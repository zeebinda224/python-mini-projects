# %%
print("Web Scrapping")
# Out:
# Web Scrapping

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\pmyls\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pmyls\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\pmyls\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pmyls\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pmyls\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pmyls\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pmyls\anaconda3\lib\site-packages (from requests) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
try:
    page = requests.get('https://www.cricbuzz.com/')

except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print('Error for link:', url)
    print(error_type,'Line:', error_info.tb_lineno)

time.sleep(2)
soup = BeautifulSoup(page.text,'html.parser')
links = soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><script src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js?loadCastFramework=1"></script><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.0/jquery.min.js" type="text/javascript"></script><style>html{scroll-behavior: smooth;}	body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-text-apple-red{color: #E90B37;}	.cb-color-light-sec{color: #464646;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent  ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/account-info" id="cb-plus-user-icon"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div></nav><style>.cb-text-link{color:#1866db;}
# .cb-plus-menu-button{padding: 8px 10px; background: #fff; border-radius: 18px; border: 0;width: 104px;height:14px;display: inline-block; text-align: center; line-height:1; }
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/94984/miny-vs-waf-14th-match-major-league-cricket-2024" target="_self" title="MI New York v Washington Freedom, 14th Match - Preview">MINY vs WAF - Preview</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/85099/glam-vs-kent-south-group-t20-blast-2024" target="_self" title="Glamorgan v Kent, South Group - Delay">GLAM vs KENT - Delay</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/93099/das-vs-cls-20th-match-lanka-premier-league-2024" target="_self" title="Dambulla Sixers v Colombo Strikers, 20th Match - DAS Won">DAS vs CLS - DAS Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/92617/trichy-vs-lkk-15th-match-tamil-nadu-premier-league-2024" target="_self" title="Trichy Grand Cholas v Lyca Kovai Kings, 15th Match - LKK Won">TRICHY vs LKK - LKK Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/94980/sfu-vs-sor-13th-match-major-league-cricket-2024" target="_self" title="San Francisco Unicorns v Seattle Orcas, 13th Match - SFU Won">SFU vs SOR - SFU Won</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">England v West Indies, 2024</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/76493/eng-vs-wi-2nd-test-england-v-west-indies-2024" target="_self" title="England v West Indies, 2nd Test - Upcoming"><span class="cb-mm-mtch-tm">England vs West Indies</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">2nd Test</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">ICC CWC League Two 2023-27</div><div class="cb-mtch-all cb-nt-live"><a href="/live-cricket-scores/94278/oman-vs-sco-13th-match-icc-cwc-league-two-2023-27" target="_self" title="Oman v Scotland, 13th Match - No Result"><span class="cb-mm-mtch-tm">Oman vs Scotland</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">13th Match</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/ ...
# }</style> <meta content="400" http-equiv="refresh"/> <div class="cb-bg-white cb-col cb-col-100 disp-flex align-center cb-qck-lnk" ng-controller="CBPlusAuth" ng-init="initiate_cb_editorial_carousal();"> <h1 class="cb-qck-acs-hdr cb-sign-up-google min-width-fit-con">Quick Access</h1> <nav class="" style="white-space: nowrap; overflow: hidden; height: 35px;"> <div class="cb-editorial-carousal-wrapper disp-flex align-center" style="height: 35px;"> <a class="cb-bg-off-white min-width-fit-con" href="/premium-subscription/user/select-plan/cricbuzz-promo" ng-if="!(user_state === 'ACTIVE' || user_state === 'ACTIVE_CANCELLED')" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="See Plans"> <span class="cb-plus-ico cb-subs-quick-access-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">See Plans</span> </a> <a class="cb-bg-off-white min-width-fit-con" href="/cricket-team/India/2" style="margin-left: 10px; padding: 8px 10px 8px 10px; border-radius: 2px;" title="Team India"> <span class="cb-plus-ico cb-teams-icon scale-080 cb-padd-rt-5"></span> <span class="cb-font-w-500">Team India</span> </a> <a class="cb-bg
width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/131053/coley-invokes-gabba-comeback-asks-west-indies-to-lift-intensity" title="Coley invokes Gabba comeback, asks West Indies to lift intensity">	Coley invokes Gabba comeback, asks West Indies to lift intensity</a></h2><div class="cb-nws-intr">The West Indies head coach is hopeful of a better show at Trent Bridge following the drubbing at Lord's</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/131058/its-just-about-trusting-our-own-game-and-making-sure-we-get-the-job-done-joshua-da-silva" title="&quot;It's just about trusting our own game and making sure we get the job done&quot; - Joshua Da Silva">"It's just about trusting our own game and making sure we get the job done" - Joshua Da Silva</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>NO U-TURNS</span></div><a href="/cricket-news/131045/bailey-shuts-the-door-on-warners-champions-trophy-hopes" title="Bailey shuts the door on Warner's Champions Trophy hopes"><img alt="Bailey shuts the door on Warner's Champions Trophy hopes" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c518502/bailey-shuts-the-door-on-warne.jpg" title="Bailey shuts the door on Warner's Champions Trophy hopes" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/131045/bailey-shuts-the-door-on-warners-champions-trophy-hopes" title="Bailey shuts the door on Warner's Champions Trophy hopes">	Bailey shuts the door on Warner's Champions Trophy hopes</a></h2><div class="cb-nws-intr">The veteran batter had left open the possibility of playing next year's marquee ICC event "if selected"</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/131044/jake-fraser-mcgurk-cooper-connolly-picked-for-england-scotland-t20is" title="Jake-Fraser McGurk, Cooper ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# The stand-in captain was also highly impressed with his team's comeback in the series after losing the opening game
#
#
# The West Indies head coach is hopeful of a better show at Trent Bridge following the drubbing at Lord's
#
#
# The veteran batter had left open the possibility of playing next year's marquee ICC event "if selected"
#
#
# The Bangladesh skipper credited Mushtaq Ahmed for his role in developing the young leggie but also insisted that local coaches are still the primary reason for Rishad's growth as a player
#
#
# The former Australian captain was at the helm of the franchise for seven seasons starting from 2018
#
#
# Kyle Mayers was the first pick of the draft and went to St Kitts & Nevis Patriots
#
#
# The international trio of Shabika Gajnabi, Cherry Ann Fraser and Djenaba Joseph, who were a part of Guyana Amazon Warriors last season, were also picked by Royals
#
#
# The 71-year-old former India cricketer has been battling the disease for a while
#
#
# The duo have worked together at Lucknow Super Giants in the IPL previously
#
#
# The decision has drawn criticism from some quarters, not least former president Rajpal Bajwa,
#
#
# Saurabh Netravalkar, Glenn Maxwell star with the ball before a Travis Head blitz assured victory
#
#
# In his first outing at the venue since downing Pakistan at the T20 World Cup, the USA captain scored 61off 45 to rekindle his batting mojo
#
#
# All the news and reports from New Zealand Women's tour of England 2024
#
#
# Belgium, who had been expected to be the chief obstacle to Jersey's progression through Group A, were handed a shock defeat by Croatia
#
#
# Both senior cricketers were picked in the squad after a long gap on the basis of their performances in domestic cricket
#
#
# News bytes that you may have missed otherwise
#
#
# It was the kind of emotion that cannot easily be explained. There was pure joy for sure. But there was also relief, and that bit of unexplained mania
#
#
# The engineer from Oracle and lead bowler of USA opens up after catching the eye of the global cricket community
#
#
# The connection with the sport among a bunch of officers from the New York Police Department led to the conception of the NYPD Cricket team
#
#
# The pace friendly wickets with indifferent bounce didn't really set the stage alight in New York with 108 being the average first innings score and 111 being the highest successful chase
#
#
# Canada is set to meet its oldest cricket rival on Saturday, and they have a score to settle
#
#
# In an exclusive interview, the South African opened up on the work that went behind honing his six-hitting, his detailed preparation against spin, his cricketing hero(es) and a lot more
#
#
# After a player of the match-winning performance in the IPL 2024 final, the left-arm quick suggested he might consider his ODI cricket future to play more franchise T20 cricket
